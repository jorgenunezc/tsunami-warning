# %%
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = os.getcwd()
folder = path+"/dataset/ts_jorge_MW8.6/"
print(folder)
# Out:
# /home/jorge/tsunami-warning/dataset/ts_jorge_MW8.6/

# %%
df = pd.read_json(folder+'DataFrame_boyas79_80viña.json') # cargar dataframe

# %%
df.head()
# Out:
#    boyas79_ts002  inu_vina80_ts002  boyas79_ts034  inu_vina80_ts034  \
# 0       0.000000                 0       0.000000                 0
# 1      -0.000002                 0       0.000017                 0
# 2      -0.000005                 0       0.000037                 0
# 3      -0.000010                 0       0.000066                 0
# 4      -0.000023                 0       0.000149                 0
#
#    boyas79_ts035  inu_vina80_ts035  boyas79_ts043  inu_vina80_ts043  \
# 0   0.000000e+00               0.0       0.000000                 0
# 1  -7.395000e-07               0.0      -0.000005                 0
# 2  -1.534100e-06               0.0      -0.000011                 0
# 3  -2.505600e-06               0.0      -0.000019                 0
# 4  -5.265200e-06               0.0      -0.000043                 0
#
#    boyas79_ts050  inu_vina80_ts050  ...  boyas79_s_026  inu_vina80_s_026  \
# 0       0.000000                 0  ...       0.000000                 0
# 1       0.000004                 0  ...       0.000016                 0
# 2       0.000009                 0  ...       0.000036                 0
# 3       0.000017                 0  ...       0.000063                 0
# 4       0.000038                 0  ...       0.000143                 0
#
#    boyas79_s_027  inu_vina80_s_027  boyas79_s_031  inu_vina80_s_031  \
# 0       0.000000                 0       0.000000                 0
# 1       0.000007                 0       0.000010                 0
# 2       0.000016                 0       0.000023                 0
# 3       0.000028                 0       0.000041                 0
# 4       0.000063                 0       0.000093                 0
#
#    boyas79_s_032  inu_vina80_s_032  boyas79_s_033  inu_vina80_s_033
# 0       0.000000                 0       0.000000                 0
# 1      -0.000010                 0       0.000012                 0
# 2      -0.000023                 0       0.000026                 0
# 3      -0.000042                 0       0.000047                 0
# 4      -0.000097                 0       0.000106                 0
#
# [5 rows x 194 columns]

# %%
df.describe()
# Out:
#        boyas79_ts002  inu_vina80_ts002  boyas79_ts034  inu_vina80_ts034  \
# count   14410.000000           14410.0   14410.000000           14410.0
# mean       -0.648908               0.0      -0.286989               0.0
# std         0.465513               0.0       0.944646               0.0
# min        -1.896200               0.0      -4.129583               0.0
# 25%        -1.011816               0.0      -0.852958               0.0
# 50%        -0.622602               0.0      -0.246065               0.0
# 75%        -0.308327               0.0       0.304436               0.0
# max         0.613058               0.0       2.168482               0.0
#
#        boyas79_ts035  inu_vina80_ts035  boyas79_ts043  inu_vina80_ts043  \
# count   14410.000000      14410.000000   14410.000000           14410.0
# mean        0.760145          0.034584      -1.097499               0.0
# std         1.369603          0.163501       0.802986               0.0
# min        -3.185444          0.000000      -3.720523               0.0
# 25%         0.027685          0.005005      -1.660192               0.0
# 50%         0.694517          0.005539      -1.105317               0.0
# 75%         1.504632          0.010796      -0.499835               0.0
# max         7.112984          1.905331       1.231893               0.0
#
#        boyas79_ts050  inu_vina80_ts050  ...  boyas79_s_026  inu_vina80_s_026  \
# count   14410.000000           14410.0  ...   14410.000000           14410.0
# mean       -0.496426               0.0  ...      -0.347874               0.0
# std         0.658526               0.0  ...       0.910496               0.0
# min        -2.300105               0.0  ...      -2.571706               0.0
# 25%        -0.907743               0.0  ...      -0.899492               0.0
# 50%        -0.444948               0.0  ...      -0.408491               0.0
# 75%         0.018315               0.0  ...       0.308116               0.0
# max         1.062584               0.0  ...       1.797382               0.0
#
#        boyas79_s_027  inu_vina80_s_027  boyas79_s_031  inu_vina80_s_031  \
# count   14410.000000           14410.0   14410.000000           14410.0
# mean       -0.003588               0.0      -0.194137               0.0
# std         0.684992               0.0       0.521097               0.0
# min        -2.704258               0.0      -1.679436               0.0
# 25%        -0.333579               0.0      -0.537303               0.0
# 50%        -0.011665               0.0      -0.160695               0.0
# 75%         0.334983               0.0       0.139470               0.0
# max         2.304038               0.0       1.408167               0.0
#
#        boyas79_s_032  inu_vina80_s_032  boyas79_s_033  inu_vina80_s_033
# count   14410.000000           14410.0   14410.000000           14410.0
# mean       -0.199643               0.0      -0.444177               0.0
# std         0.912928               0.0       0.740162               0.0
# min        -2.615318               0.0      -2.550962               0.0
# 25%        -0.791233               0.0      -0.954297               0.0
# 50%        -0.307547               0.0      -0.431764               0.0
# 75%         0.284067               0.0       0.107864               0.0
# max         2.860675               0.0       1.148816               0.0
#
# [8 rows x 194 columns]

# %%
print(df.isna().sum())
# Out:
# boyas79_ts002       0
# inu_vina80_ts002    0
# boyas79_ts034       0
# inu_vina80_ts034    0
# boyas79_ts035       0
#                    ..
# inu_vina80_s_031    0
# boyas79_s_032       0
# inu_vina80_s_032    0
# boyas79_s_033       0
# inu_vina80_s_033    0
# Length: 194, dtype: int64

# %%
columns = df.columns

# %%
files = []
for file in columns:
    if file.endswith("002"):
        files.append(file)
files.sort()
print(files)
# Out:
# ['boyas79_ts002', 'inu_vina80_ts002']

# %%
plt.figure(figsize=(24,24))
sns.heatmap(df[files].corr(), vmax=1.0,vmin = -1.0 ,linewidths=0.1,
            square=True,annot=True,cmap='viridis',linecolor="k")
sns.set(font_scale=2)
plt.title('Correlacion entre caracteristicas')
plt.rc('xtick', labelsize=17) 
plt.rc('ytick', labelsize=17)
plt.xticks(rotation='vertical')
plt.yticks(rotation='horizontal')
plt.rcParams["font.weight"] = "bold"
plt.show()

# %% [markdown]
# **comentario :** se aprecia una correlacion cercana a 1 entre las boyas del mar, lo cual no ayudaria en el entrenamiento de la red se considerara la boya28 que es la que esta más mar adentro.

# %%
plt.ion()
plt.rc('xtick', labelsize=13) 
plt.rc('ytick', labelsize=13)
plt.figure(figsize=(14,6), dpi=120)
plt.xlabel('Time',fontsize=17)
plt.ylabel('Altura de inundación [m]',fontsize=17)
plt.plot(df['inu_valpo6_E3_9.0'], color='m', linewidth=1.0)
plt.ylim(-1,20)
plt.twinx()
plt.plot(df['boyas28_E3_9.0'], color='#1C7C54', linewidth=1.0)
plt.ylim(-25,20)
ax = plt.gca()
#ax.invert_yaxis()
plt.ylabel('Altura de ola [m]',fontsize=17)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/machinelearning/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'inu_valpo6_E3_9.0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-541a2e76d9d2> in <module>
#       5 plt.xlabel('Time',fontsize=17)
#       6 plt.ylabel('Altura de inundación [m]',fontsize=17)
# ----> 7 plt.plot(df['inu_valpo6_E3_9.0'], color='m', linewidth=1.0)
#       8 plt.ylim(-1,20)
#       9 plt.twinx()
#
# ~/anaconda3/envs/machinelearning/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/envs/machinelearning/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'inu_valpo6_E3_9.0'
